# %% [markdown]
# # Desafio Técnico em Python

# %% [markdown]
# ## Instalando dependências e importando bibliotecas

# %%
# !pip install pandas==1.5.3 -q
# !pip install pandas-gbq==0.17.4 -q
# !pip install google-cloud-bigquery==3.16.0 -q
# !pip install pyarrow==6.0.0 -q
# !pip install basedosdados -q
import basedosdados as bd
import pandas as pd
import plotly.express as px

# Billing project ID (Google Cloud Platform)
# !!! Troque pelo seu project ID
PROJECT_ID = "teste-prefeitura-413816"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 13.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 1.5.3 which is incompatible.
# xarray 2024.6.0 requires pandas>=2.0, but you have pandas 1.5.3 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 57.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.15.0 requires pyarrow>=8.0.0, but you have pyarrow 7.0.0 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 7.0.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 3.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.15.0 requires pyarrow>=8.0.0, but you have pyarrow 7.0.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 44.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.15.0 requires pyarrow>=8.0.0, but you have pyarrow 6.0.0 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 6.0.0 which is incompatible.
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.0/204.0 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.2/135.2 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 62.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 6.5 MB/s eta 0:00:00
#   Building wheel for ckanapi (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.15.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.16.0, but you have google-cloud-bigquery 2.30.1 which is incompatible.
# bigframes 1.15.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.42.3 which is incompatible.
# bigframes 1.15.0 requires pyarrow>=8.0.0, but you have pyarrow 6.0.0 which is incompatible.
# dask 2024.7.1 requires click>=8.1, but you have click 8.0.3 which is incompatible.
# dopamine-rl 4.0.9 requires tqdm>=4.64.1, but you have tqdm 4.50.2 which is incompatible.
# google-cloud-bigtable 2.26.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.

# %% [markdown]
# ## Paleta de cores

# %%
BLUE_HIGHLIGHT = "#3d87ff"
LIGHT_GRAY = "#9b9b9b"

# %% [markdown]
# ## Requisitando dataframes

# %%
query_chamados_01_04 = "SELECT * FROM `datario.adm_central_atendimento_1746.chamado` WHERE DATE(data_inicio) = '2023-04-01'"
query_bairros = "SELECT * FROM `datario.dados_mestres.bairro`"
query_chamados_2022_2023 = "SELECT data_inicio, tipo, subtipo FROM `datario.adm_central_atendimento_1746.chamado` WHERE DATE(data_inicio) BETWEEN '2022-01-01' AND '2023-12-31'"
query_eventos = "SELECT * FROM `datario.turismo_fluxo_visitantes.rede_hoteleira_ocupacao_eventos`"

# %%
# Executa queries e cria DataFrames pandas de todos os resultados

# Chamados realizados no dia 01/04/2023
bd_df_chamados_01_04 = bd.read_sql(query_chamados_01_04, billing_project_id=PROJECT_ID)
df_chamados_01_04 = pd.DataFrame(data = bd_df_chamados_01_04)

# Tabela de bairros
bd_df_bairros = bd.read_sql(query_bairros, billing_project_id=PROJECT_ID)
df_bairros = pd.DataFrame(data = bd_df_bairros)

# Chamados entre 2022 e 2023
bd_df_chamados_2022_2023 = bd.read_sql(query_chamados_2022_2023, billing_project_id=PROJECT_ID)
df_chamados_2022_2023 = pd.DataFrame(data = bd_df_chamados_2022_2023)

# Tabela de eventos
bd_df_eventos = bd.read_sql(query_eventos, billing_project_id=PROJECT_ID)
df_eventos = pd.DataFrame(data = bd_df_eventos)
# Out:
# Downloading: 100%|██████████| 1756/1756 [00:00<00:00, 2552.83rows/s]
# Downloading: 100%|██████████| 164/164 [00:03<00:00, 46.29rows/s]
# Downloading: 100%|██████████| 1634336/1634336 [01:16<00:00, 21287.24rows/s]
# Downloading: 100%|██████████| 4/4 [00:00<00:00, 21.98rows/s]

# %% [markdown]
# ## Funções

# %%
def plot_bar(data, x, y, color, text, title, subtitle, labels, color_discrete_sequence=None, orientation='v'):
  fig = px.bar(data,
               x = x,
               y = y,
               color = color,
               text = text,
               title=title + f' <br><sup>{subtitle}</sup>',
               labels=labels,
               color_discrete_sequence=color_discrete_sequence)
  fig.update_traces(textposition='outside', showlegend=False)
  fig.update_layout(width=1080, bargap=0.2)
  fig.show()

# %% [markdown]
# ## Pergunta 1
# Quantos chamados foram abertos no dia 01/04/2023?

# %%
chamados_04_2023 = df_chamados_2022_2023.loc[df_chamados_2022_2023['data_inicio'].between('2023-04-01', '2023-04-08')]
chamados_04_2023['data_inicio'] = chamados_04_2023['data_inicio'].dt.date

chamados_04_2023_por_dia = chamados_04_2023.groupby('data_inicio')['data_inicio'].count().reset_index(name='chamados')


plot_bar(data=chamados_04_2023_por_dia,
         x='data_inicio',
         y='chamados',
         color='data_inicio',
         text='chamados',
         title='Chamados por dia nos dias 01/04/23 a 07/04/23',
         subtitle='1756 chamados foram abertos no dia 01/04/23',
         labels={'data_inicio': 'Dia', 'chamados': 'Chamados'},
         color_discrete_sequence=[BLUE_HIGHLIGHT, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY]
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6619e3f8-6e9e-4390-8819-298eedf444c3" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6619e3f8-6e9e-4390-8819-298eedf444c3")) {                    Plotly.newPlot(                        "6619e3f8-6e9e-4390-8819-298eedf444c3",                        [{"alignmentgroup":"True","hovertemplate":"Dia=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04-01","marker":{"color":"#3d87ff","pattern":{"shape":""}},"name":"2023-04-01","offsetgroup":"2023-04-01","orientation":"v","showlegend":false,"text":[1756.0],"textposition":"outside","x":["2023-04-01"],"xaxis":"x","y":[1756],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dia=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04-02","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"2023-04-02","offsetgroup":"2023-04-02","orientation":"v","showlegend":false,"text":[1227.0],"textposition":"outside","x":["2023-04-02"],"xaxis":"x","y":[1227],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dia=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04-03","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"2023-04-03","offsetgroup":"2023-04-03","orientation":"v","showlegend":false,"text":[2989.0],"textposition":"outside","x":["2023-04-03"],"xaxis":"x","y":[2989],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dia=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04-04","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"2023-04-04","offsetgroup":"2023-04-04","orientation":"v","showlegend":false,"text":[3074.0],"textposition":"outside","x":["2023-04-04"],"xaxis":"x","y":[3074],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dia=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04-05","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"2023-04-05","offsetgroup":"2023-04-05","orientation":"v","showlegend":false,"text":[2840.0],"textposition":"outside","x":["2023-04-05"],"xaxis":"x","y":[2840],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dia=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04-06","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"2023-04-06","offsetgroup":"2023-04-06","orientation":"v","showlegend":false,"text":[2219.0],"textposition":"outside","x":["2023-04-06"],"xaxis":"x","y":[2219],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Dia=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023-04-07","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"2023-04-07","offsetgroup":"2023-04-07","orientation":"v","showlegend":false,"text":[1043.0],"textposition":"outside","x":["2023-04-07"],"xaxis":"x","y":[1043],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#72 ...

# %% [markdown]
# ## Pergunta 2
# Qual o tipo de chamado que teve mais teve chamados abertos no dia 01/04/2023?

# %%
# Agrupa por tipo
df_chamados_por_tipo = df_chamados_01_04.groupby('tipo')['tipo'].count().reset_index(name='chamados')

# Chamados por tipo em ordem decrescente
df_chamados_por_tipo = df_chamados_por_tipo.sort_values(by='chamados', ascending=False)

plot_bar(data=df_chamados_por_tipo.iloc[0:5],
         x='tipo',
         y='chamados',
         color='tipo',
         text='chamados',
         title='Chamados por tipo no dia 01/04/2023',
         subtitle='"Estacionamento Irregular" foi o tipo de Chamado mais aberto neste dia',
         labels={'tipo': 'Tipo de Chamado', 'chamados': 'Chamados'},
         color_discrete_sequence=[BLUE_HIGHLIGHT, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY]
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="20545b69-85d0-4bbf-a604-023d9cefb9ba" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20545b69-85d0-4bbf-a604-023d9cefb9ba")) {                    Plotly.newPlot(                        "20545b69-85d0-4bbf-a604-023d9cefb9ba",                        [{"alignmentgroup":"True","hovertemplate":"Tipo de Chamado=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Estacionamento irregular","marker":{"color":"#3d87ff","pattern":{"shape":""}},"name":"Estacionamento irregular","offsetgroup":"Estacionamento irregular","orientation":"v","showlegend":false,"text":[366.0],"textposition":"outside","x":["Estacionamento irregular"],"xaxis":"x","y":[366],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Chamado=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Remo\u00e7\u00e3o Gratuita","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Remo\u00e7\u00e3o Gratuita","offsetgroup":"Remo\u00e7\u00e3o Gratuita","orientation":"v","showlegend":false,"text":[196.0],"textposition":"outside","x":["Remo\u00e7\u00e3o Gratuita"],"xaxis":"x","y":[196],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Chamado=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manuten\u00e7\u00e3o de ilumina\u00e7\u00e3o p\u00fablica","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Manuten\u00e7\u00e3o de ilumina\u00e7\u00e3o p\u00fablica","offsetgroup":"Manuten\u00e7\u00e3o de ilumina\u00e7\u00e3o p\u00fablica","orientation":"v","showlegend":false,"text":[122.0],"textposition":"outside","x":["Manuten\u00e7\u00e3o de ilumina\u00e7\u00e3o p\u00fablica"],"xaxis":"x","y":[122],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Chamado=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Limpeza de logradouros","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Limpeza de logradouros","offsetgroup":"Limpeza de logradouros","orientation":"v","showlegend":false,"text":[116.0],"textposition":"outside","x":["Limpeza de logradouros"],"xaxis":"x","y":[116],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Chamado=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Perturba\u00e7\u00e3o do sossego","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Perturba\u00e7\u00e3o do sossego","offsetgroup":"Perturba\u00e7\u00e3o do sossego","orientation":"v","showlegend":false,"text":[111.0],"textposition":"outside","x":["Perturba\u00e7\u00e3o do sossego"],"xaxis":"x","y":[111],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale" ...

# %% [markdown]
# ## Pergunta 3
# Quais os nomes dos 3 bairros que mais tiveram chamados abertos nesse dia?

# %%
# Merge, similar a inner join do SQL, dos DataFrames de Chamados e Bairros
df_merge_chamados_bairros = pd.merge(df_chamados_01_04, df_bairros, on='id_bairro')

# Agrupa os dados por bairro e quantidade de chamados de cada bairro
df_chamados_por_bairro = df_merge_chamados_bairros.groupby('nome')['nome'].count().reset_index(name='chamados')

# Chamados por bairro em ordem decrescente
df_chamados_por_bairro = df_chamados_por_bairro.sort_values(by='chamados', ascending=False)

plot_bar(data=df_chamados_por_bairro.iloc[0:3],
         x='nome',
         y='chamados',
         color='nome',
         text='chamados',
         title='Bairros com os maiores números de chamados no dia 01/04/2023',
         subtitle='Campo grande é o bairro com o maior número de chamados abertos neste dia: 113 chamados',
         labels={'nome': 'Bairro', 'chamados': 'Chamados'},
         color_discrete_sequence=[BLUE_HIGHLIGHT, LIGHT_GRAY, LIGHT_GRAY]
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f177ee2e-ed9a-4365-95de-ca9e8b30ea91" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f177ee2e-ed9a-4365-95de-ca9e8b30ea91")) {                    Plotly.newPlot(                        "f177ee2e-ed9a-4365-95de-ca9e8b30ea91",                        [{"alignmentgroup":"True","hovertemplate":"Bairro=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Campo Grande","marker":{"color":"#3d87ff","pattern":{"shape":""}},"name":"Campo Grande","offsetgroup":"Campo Grande","orientation":"v","showlegend":false,"text":[113.0],"textposition":"outside","x":["Campo Grande"],"xaxis":"x","y":[113],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Bairro=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tijuca","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Tijuca","offsetgroup":"Tijuca","orientation":"v","showlegend":false,"text":[89.0],"textposition":"outside","x":["Tijuca"],"xaxis":"x","y":[89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Bairro=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Barra da Tijuca","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Barra da Tijuca","offsetgroup":"Barra da Tijuca","orientation":"v","showlegend":false,"text":[59.0],"textposition":"outside","x":["Barra da Tijuca"],"xaxis":"x","y":[59],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %% [markdown]
# ## Pergunta 4
# Qual o nome da subprefeitura com mais chamados abertos nesse dia?

# %%
# Agrupa os dados por subprefeitura e quantidade de chamados de cada subprefeitura
df_chamados_subprefeitura = df_merge_chamados_bairros.groupby('subprefeitura')['subprefeitura'].count().reset_index(name = 'chamados')

# Chamados por prefeitura em ordem decrescente
df_chamados_subprefeitura_desc = df_chamados_subprefeitura.sort_values(by = "chamados", ascending=False)

plot_bar(data=df_chamados_subprefeitura_desc.iloc[0:5],
         x='subprefeitura',
         y='chamados',
         color='subprefeitura',
         text='chamados',
         title='Subprefeituras com os maiores números de chamados no dia 01/04/2023',
         subtitle='A Zona Norte é a subprefeitura com o maior número de chamados abertos neste dia: 510 chamados',
         labels={'subprefeitura': 'Subprefeitura', 'chamados': 'Chamados'},
         color_discrete_sequence=[BLUE_HIGHLIGHT, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY, LIGHT_GRAY]
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8d953d42-59f8-4390-a544-c6987c12fba6" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d953d42-59f8-4390-a544-c6987c12fba6")) {                    Plotly.newPlot(                        "8d953d42-59f8-4390-a544-c6987c12fba6",                        [{"alignmentgroup":"True","hovertemplate":"Subprefeitura=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zona Norte","marker":{"color":"#3d87ff","pattern":{"shape":""}},"name":"Zona Norte","offsetgroup":"Zona Norte","orientation":"v","showlegend":false,"text":[510.0],"textposition":"outside","x":["Zona Norte"],"xaxis":"x","y":[510],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Subprefeitura=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zona Oeste","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Zona Oeste","offsetgroup":"Zona Oeste","orientation":"v","showlegend":false,"text":[238.0],"textposition":"outside","x":["Zona Oeste"],"xaxis":"x","y":[238],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Subprefeitura=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zona Sul","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Zona Sul","offsetgroup":"Zona Sul","orientation":"v","showlegend":false,"text":[233.0],"textposition":"outside","x":["Zona Sul"],"xaxis":"x","y":[233],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Subprefeitura=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grande Tijuca","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Grande Tijuca","offsetgroup":"Grande Tijuca","orientation":"v","showlegend":false,"text":[159.0],"textposition":"outside","x":["Grande Tijuca"],"xaxis":"x","y":[159],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Subprefeitura=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jacarepagu\u00e1","marker":{"color":"#9b9b9b","pattern":{"shape":""}},"name":"Jacarepagu\u00e1","offsetgroup":"Jacarepagu\u00e1","orientation":"v","showlegend":false,"text":[145.0],"textposition":"outside","x":["Jacarepagu\u00e1"],"xaxis":"x","y":[145],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222 ...

# %% [markdown]
# ## Pergunta 5
# Existe algum chamado aberto nesse dia que não foi associado a um bairro ou subprefeitura na tabela de bairros? Se sim, por que isso acontece?

# %%
# Realiza o LEFT JOIN das tabelas de Chamados e Bairros
df_merge_left_chamados_bairros = pd.merge(df_chamados_01_04, df_bairros, how='left',  on='id_bairro')

# Seleciona os chamados não associados a bairro ou subprefeitura na tabela Bairro
df_merge_chamados_bairros_null = df_merge_left_chamados_bairros[df_merge_left_chamados_bairros['nome'].isnull() | df_merge_left_chamados_bairros['subprefeitura'].isnull()]

# Agrupa por tipo
df_chamados_sem_bairro_por_tipo = df_merge_chamados_bairros_null.groupby('tipo')['tipo'].count().reset_index(name='chamados')

# Chamados por tipo em ordem decrescente
df_chamados_sem_bairro_por_tipo = df_chamados_sem_bairro_por_tipo.sort_values(by='chamados', ascending=False)

plot_bar(data=df_chamados_sem_bairro_por_tipo,
         x='chamados',
         y='tipo',
         color='tipo',
         text='chamados',
         title='Chamados não associados a bairro no dia 01/04/2023 agrupados por Tipo',
         subtitle='A maioria dos chamados neste dia foram do tipo Ônibus',
         labels={'tipo': 'Tipo', 'chamados': 'Chamados'},
         orientation='h'
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fedb56a0-9e0f-4810-a7a2-ceac3b2d5b2c" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fedb56a0-9e0f-4810-a7a2-ceac3b2d5b2c")) {                    Plotly.newPlot(                        "fedb56a0-9e0f-4810-a7a2-ceac3b2d5b2c",                        [{"alignmentgroup":"True","hovertemplate":"Tipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u00d4nibus","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u00d4nibus","offsetgroup":"\u00d4nibus","orientation":"h","showlegend":false,"text":[50.0],"textposition":"outside","x":[50],"xaxis":"x","y":["\u00d4nibus"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Atendimento ao cidad\u00e3o","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Atendimento ao cidad\u00e3o","offsetgroup":"Atendimento ao cidad\u00e3o","orientation":"h","showlegend":false,"text":[18.0],"textposition":"outside","x":[18],"xaxis":"x","y":["Atendimento ao cidad\u00e3o"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alvar\u00e1","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Alvar\u00e1","offsetgroup":"Alvar\u00e1","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["Alvar\u00e1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRT (corredor expresso de \u00f4nibus)","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"BRT (corredor expresso de \u00f4nibus)","offsetgroup":"BRT (corredor expresso de \u00f4nibus)","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["BRT (corredor expresso de \u00f4nibus)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Defesa do Consumidor","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Defesa do Consumidor","offsetgroup":"Defesa do Consumidor","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["Defesa do Consumidor"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Estacionamento irregular","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Estacionamento irregular","offsetgroup":"Estacionamento irregular","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["Estacionamento irregular"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transporte Especial Complementar - TEC","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Transporte Especial Complementar - TEC","offsetgroup":"Transporte Especial Complementar - TEC","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["Transporte Especial Complementar - TEC"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556 ...

# %%
# Agrupa por subtipo
df_chamados_sem_bairro_por_tipo = df_merge_chamados_bairros_null.groupby('subtipo')['subtipo'].count().reset_index(name='chamados')

# Chamados por subtipo em ordem decrescente
df_chamados_sem_bairro_por_tipo = df_chamados_sem_bairro_por_tipo.sort_values(by='chamados', ascending=False)

plot_bar(data=df_chamados_sem_bairro_por_tipo,
         x='chamados',
         y='subtipo',
         color='subtipo',
         text='chamados',
         title='Chamados não associados a bairro no dia 01/04/2023 agrupador por Subtipo',
         subtitle='A maioria dos chamados do tipo Ônibus foram realizados para Verificação de ar condicionado inoperante',
         labels={'subtipo': 'subtipo', 'chamados': 'Chamados'},
         orientation='h'
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9e1487d9-8d45-4ddc-afb4-ccf6e4ce7ad3" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e1487d9-8d45-4ddc-afb4-ccf6e4ce7ad3")) {                    Plotly.newPlot(                        "9e1487d9-8d45-4ddc-afb4-ccf6e4ce7ad3",                        [{"alignmentgroup":"True","hovertemplate":"subtipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Verifica\u00e7\u00e3o de ar condicionado inoperante no \u00f4nibus","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Verifica\u00e7\u00e3o de ar condicionado inoperante no \u00f4nibus","offsetgroup":"Verifica\u00e7\u00e3o de ar condicionado inoperante no \u00f4nibus","orientation":"h","showlegend":false,"text":[49.0],"textposition":"outside","x":[49],"xaxis":"x","y":["Verifica\u00e7\u00e3o de ar condicionado inoperante no \u00f4nibus"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"subtipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solicita\u00e7\u00e3o de corre\u00e7\u00e3o de falhas e de cadastro no portal e app 1746","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Solicita\u00e7\u00e3o de corre\u00e7\u00e3o de falhas e de cadastro no portal e app 1746","offsetgroup":"Solicita\u00e7\u00e3o de corre\u00e7\u00e3o de falhas e de cadastro no portal e app 1746","orientation":"h","showlegend":false,"text":[17.0],"textposition":"outside","x":[17],"xaxis":"x","y":["Solicita\u00e7\u00e3o de corre\u00e7\u00e3o de falhas e de cadastro no portal e app 1746"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"subtipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fiscaliza\u00e7\u00e3o de estacionamento irregular de ve\u00edculo","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fiscaliza\u00e7\u00e3o de estacionamento irregular de ve\u00edculo","offsetgroup":"Fiscaliza\u00e7\u00e3o de estacionamento irregular de ve\u00edculo","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["Fiscaliza\u00e7\u00e3o de estacionamento irregular de ve\u00edculo"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"subtipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fiscaliza\u00e7\u00e3o de irregularidades em linha de \u00f4nibus","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Fiscaliza\u00e7\u00e3o de irregularidades em linha de \u00f4nibus","offsetgroup":"Fiscaliza\u00e7\u00e3o de irregularidades em linha de \u00f4nibus","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["Fiscaliza\u00e7\u00e3o de irregularidades em linha de \u00f4nibus"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"subtipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fiscaliza\u00e7\u00e3o do transporte complementar","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Fiscaliza\u00e7\u00e3o do transporte complementar","offsetgroup":"Fiscaliza\u00e7\u00e3o do transporte complementar","orientation":"h","showlegend":false,"text":[1.0],"textposition":"outside","x":[1],"xaxis":"x","y":["Fiscaliza\u00e7\u00e3o do transporte complementar"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"subtipo=%{y}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solicita\u00e7\u00e3o da grava\u00e7\u00e3o do atendimento 1746","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Solicita\u00e7\u00e3o da grava\u00e7\u00e3o do atendimento 1746","of ...

# %% [markdown]
# ### Porque isto acontece?
#
# - Ônibus, BRT e TEC: Ônibus e Unidades de transporte podem não estar associadas a um bairro, ou estar associadas a mais de um bairro, impossibilitando a associação no sistema.
# - Atendimento ao cidadão e Alvará: Solicitações de suporte ou orientação realizadas no app móvel no smartphone não estão associadas a uma localidade.
# - Defesa do consumidor: Chamados de Verificação de problemas com produtos ou serviços também não necessáriamente estão associados a um bairro ou subprefeitura.

# %% [markdown]
# ## Pergunta 6
# Quantos chamados com o subtipo "Perturbação do sossego" foram abertos desde 01/01/2022 até 31/12/2023 (incluindo extremidades)?

# %%
chamados_sossego = df_chamados_2022_2023.loc[df_chamados_2022_2023['subtipo'] == 'Perturbação do sossego']

print(f"O número de chamados com subtipo 'Perturbação do sossego' abertos desde 01/01/2022 até 31/12/2023 é: {len(chamados_sossego)} chamados")
# Out:
# O número de chamados com subtipo 'Perturbação do sossego' abertos desde 01/01/2022 até 31/12/2023 é: 42830 chamados

# %% [markdown]
# ## Pergunta 7
# Selecione os chamados com esse subtipo que foram abertos durante os eventos contidos na tabela de eventos (Reveillon, Carnaval e Rock in Rio).

# %%
# Função que adiciona a coluna de evento ao df chamados_eventos de acordo com a data

def adiciona_evento(chamados_eventos, df_eventos):
  """
  Percorre um dataframe chamados_eventos linha a linha, analisa o campo data_inicio
  e adiciona o nome do evento correspondente a uma nova coluna 'evento'.

  Args:
    chamados_eventos: DataFrame com os chamados.
    df_eventos: DataFrame com os eventos.

  Returns:
    DataFrame com a nova coluna 'evento'.
  """
  chamados_eventos['evento'] = ''
  for index, row in chamados_eventos.iterrows():
    data_inicio = row['data_inicio']
    evento_encontrado = False
    for _, event_row in df_eventos.iterrows():
      if data_inicio >= event_row['data_inicial'] and data_inicio <= event_row['data_final']:
        chamados_eventos.loc[index, 'evento'] = event_row['evento']
        evento_encontrado = True
        break
    if not evento_encontrado:
      chamados_eventos.loc[index, 'evento'] = 'Sem evento'
  return chamados_eventos

# %%
# Adiciona o evento de cada chamado
chamados_sossego_eventos = adiciona_evento(chamados_sossego, df_eventos)

# Filtra apenas os chamados com evento
chamados_sossego_eventos = chamados_sossego_eventos[chamados_sossego_eventos['evento'] != 'Sem evento']

chamados_sossego_eventos
# Out:
#                 data_inicio                    tipo                 subtipo  \
# 3691    2022-09-11 08:22:49  Perturbação do sossego  Perturbação do sossego
# 3692    2022-09-11 14:21:57  Perturbação do sossego  Perturbação do sossego
# 3698    2022-09-10 20:50:59  Perturbação do sossego  Perturbação do sossego
# 3700    2022-09-11 13:34:55  Perturbação do sossego  Perturbação do sossego
# 3701    2022-09-11 01:14:32  Perturbação do sossego  Perturbação do sossego
# ...                     ...                     ...                     ...
# 1507891 2023-02-18 19:23:34  Perturbação do sossego  Perturbação do sossego
# 1507911 2023-02-18 12:02:57  Perturbação do sossego  Perturbação do sossego
# 1507922 2023-02-18 17:07:39  Perturbação do sossego  Perturbação do sossego
# 1507923 2023-02-21 17:56:52  Perturbação do sossego  Perturbação do sossego
# 1507925 2023-02-18 12:08:07  Perturbação do sossego  Perturbação do sossego
#
#               evento
# 3691     Rock in Rio
# 3692     Rock in Rio
# 3698     Rock in Rio
# 3700     Rock in Rio
# 3701     Rock in Rio
# ...              ...
# 1507891     Carnaval
# 1507911     Carnaval
# 1507922     Carnaval
# 1507923     Carnaval
# 1507925     Carnaval
#
# [1214 rows x 4 columns]

# %% [markdown]
# ### Observação
# Embora seja possível realizar este JOIN com Python, é muito menos custoso, mais performático e simples fazê-lo diretamente com SQL, conforme o exemplo abaixo:

# %%
# Query
query_chamados_sossego_eventos = """
SELECT *
FROM `datario.adm_central_atendimento_1746.chamado` Chamados
INNER JOIN `datario.turismo_fluxo_visitantes.rede_hoteleira_ocupacao_eventos` Eventos
ON (DATE(Chamados.data_inicio) BETWEEN Eventos.data_inicial AND Eventos.data_final)
WHERE subtipo = "Perturbação do sossego"
"""

bd_df_chamados_sossego_eventos = bd.read_sql(query_chamados_sossego_eventos, billing_project_id=PROJECT_ID)
df_chamados_sossego_eventos = pd.DataFrame(data = bd_df_chamados_sossego_eventos)
df_chamados_sossego_eventos.head()
# Out:
# Downloading: 100%|██████████| 1214/1214 [00:00<00:00, 1674.15rows/s]
#   id_chamado id_origem_ocorrencia         data_inicio            data_fim  \
# 0   18330346                   13 2023-02-19 11:58:16 2023-02-19 16:15:42
# 1   18333177                   11 2023-02-20 23:49:58 2023-02-24 08:17:28
# 2   18330400                   11 2023-02-19 12:32:41 2023-02-27 09:02:58
# 3   18329191                   11 2023-02-18 18:36:46 2023-02-24 10:35:25
# 4   18330619                   13 2023-02-19 15:03:45 2023-02-27 09:20:48
#
#   id_bairro id_territorialidade id_logradouro  numero_logradouro  \
# 0        64                   3         81034                232
# 1        38                   2         37515                144
# 2        24                   2         80788               <NA>
# 3        90                   3         54205                469
# 4       128                   4        232686                 81
#
#   id_unidade_organizacional                  nome_unidade_organizacional  ...  \
# 0                        70  GM-RIO - Guarda Municipal do Rio de Janeiro  ...
# 1                        70  GM-RIO - Guarda Municipal do Rio de Janeiro  ...
# 2                        70  GM-RIO - Guarda Municipal do Rio de Janeiro  ...
# 3                        70  GM-RIO - Guarda Municipal do Rio de Janeiro  ...
# 4                        70  GM-RIO - Guarda Municipal do Rio de Janeiro  ...
#
#     situacao tipo_situacao justificativa_status reclamacoes data_particao  \
# 0  Encerrado      Atendido                 None           0    2023-02-01
# 1  Encerrado  Não atendido                 None           0    2023-02-01
# 2  Encerrado  Não atendido                 None           0    2023-02-01
# 3  Encerrado  Não atendido                 None           1    2023-02-01
# 4  Encerrado  Não atendido                 None           0    2023-02-01
#
#                      ano data_inicial  data_final    evento  taxa_ocupacao
# 0  18/02 a 21/02 de 2023   2023-02-18  2023-02-21  Carnaval         0.9554
# 1  18/02 a 21/02 de 2023   2023-02-18  2023-02-21  Carnaval         0.9554
# 2  18/02 a 21/02 de 2023   2023-02-18  2023-02-21  Carnaval         0.9554
# 3  18/02 a 21/02 de 2023   2023-02-18  2023-02-21  Carnaval         0.9554
# 4  18/02 a 21/02 de 2023   2023-02-18  2023-02-21  Carnaval         0.9554
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Pergunta 8
# Quantos chamados desse subtipo foram abertos em cada evento?

# %%
# Agrupa chamados por evento
chamados_sossego_por_evento = chamados_sossego_eventos.groupby('evento')['evento'].count().reset_index(name='chamados')

plot_bar(data=chamados_sossego_por_evento,
         x='evento',
         y='chamados',
         color='evento',
         text='chamados',
         title='Chamados de "Perturbação de sossego" criados em cada evento nos anos 2022 e 2023',
         subtitle='O Rock in Rio foi o evento com mais chamados deste subtipo criados nos dois anos',
         labels={'evento': 'Evento', 'chamados': 'Chamados'}
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d601209-12ea-4826-9698-46d7633fa52e" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d601209-12ea-4826-9698-46d7633fa52e")) {                    Plotly.newPlot(                        "5d601209-12ea-4826-9698-46d7633fa52e",                        [{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carnaval","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Carnaval","offsetgroup":"Carnaval","orientation":"v","showlegend":false,"text":[241.0],"textposition":"outside","x":["Carnaval"],"xaxis":"x","y":[241],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Reveillon","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Reveillon","offsetgroup":"Reveillon","orientation":"v","showlegend":false,"text":[139.0],"textposition":"outside","x":["Reveillon"],"xaxis":"x","y":[139],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eChamados=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rock in Rio","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Rock in Rio","offsetgroup":"Rock in Rio","orientation":"v","showlegend":false,"text":[834.0],"textposition":"outside","x":["Rock in Rio"],"xaxis":"x","y":[834],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333 ...

# %% [markdown]
# ## Pergunta 9
# Qual evento teve a maior média diária de chamados abertos desse subtipo?

# %%
# Copia DataFrame com chamados do subtipo 'Perturbação do sossego' com a coluna de eventos criado na Pergunta 7
chamados_sossego_eventos_copy = chamados_sossego_eventos.copy()

# Transforma a coluna data_inicio do tipo DataTime para Date, de forma a poder agrupar por data_inicio
chamados_sossego_eventos_copy['data_inicio'] = chamados_sossego_eventos_copy['data_inicio'].dt.date

# Agrupa os chamados por evento e data_inicio
chamados_por_dia_evento = chamados_sossego_eventos_copy.groupby(['evento', 'data_inicio'])['data_inicio'].count().reset_index(name='chamados')

# Calcula a média de chamados por dia para cada evento e arredonda para 2 casas decimais
media_chamados_por_dia = chamados_por_dia_evento.groupby('evento')['chamados'].mean().round(2).reset_index(name='media_chamados_por_dia')

plot_bar(data=media_chamados_por_dia,
         x='evento',
         y='media_chamados_por_dia',
         color='evento',
         text='media_chamados_por_dia',
         title='Eventos com a maior média de chamados de "Perturbação de sossego" por dia',
         subtitle='O Rock in Rio foi o evento com a maior média de chamados por dia deste subtipo entre os três eventos',
         labels={'evento': 'Evento', 'media_chamados_por_dia': 'Média de Chamados por Dia'}
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7298683a-b3d1-45af-a004-ff2c8db33d1f" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7298683a-b3d1-45af-a004-ff2c8db33d1f")) {                    Plotly.newPlot(                        "7298683a-b3d1-45af-a004-ff2c8db33d1f",                        [{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eM\u00e9dia de Chamados por Dia=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carnaval","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Carnaval","offsetgroup":"Carnaval","orientation":"v","showlegend":false,"text":[60.25],"textposition":"outside","x":["Carnaval"],"xaxis":"x","y":[60.25],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eM\u00e9dia de Chamados por Dia=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Reveillon","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Reveillon","offsetgroup":"Reveillon","orientation":"v","showlegend":false,"text":[46.33],"textposition":"outside","x":["Reveillon"],"xaxis":"x","y":[46.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eM\u00e9dia de Chamados por Dia=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rock in Rio","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Rock in Rio","offsetgroup":"Rock in Rio","orientation":"v","showlegend":false,"text":[119.14],"textposition":"outside","x":["Rock in Rio"],"xaxis":"x","y":[119.14],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...

# %% [markdown]
# ## Pergunta 10
# Compare as médias diárias de chamados abertos desse subtipo durante os eventos específicos (Reveillon, Carnaval e Rock in Rio) e a média diária de chamados abertos desse subtipo considerando todo o período de 01/01/2022 até 31/12/2023.

# %%
# Calcula a média diária de chamados abertos para todo o período
chamados_sossego_geral = chamados_sossego.copy()
chamados_sossego_geral['data_inicio'] = chamados_sossego_geral['data_inicio'].dt.date
chamados_sossego_geral = chamados_sossego_geral.groupby('data_inicio')['data_inicio'].count().reset_index(name='chamados')
media_chamados_sossego = chamados_sossego_geral['chamados'].mean().round(2)

# Adiciona a média geral ao dataframe media_chamados_por_dia
nova_linha = pd.DataFrame({'evento': ['Geral'], 'media_chamados_por_dia': [media_chamados_sossego]})
if media_chamados_por_dia[media_chamados_por_dia['evento'] == 'Geral'].empty:
  media_chamados_por_dia = pd.concat([media_chamados_por_dia, nova_linha], ignore_index=True)

# %%
media_chamados_por_dia['media_chamados_por_dia']
# Out:
# 0     60.25
# 1     46.33
# 2    119.14
# 3     61.98
# Name: media_chamados_por_dia, dtype: float64

# %%
media_geral = media_chamados_por_dia.loc[media_chamados_por_dia.evento == 'Geral'].media_chamados_por_dia.values[0]

fig = px.bar(media_chamados_por_dia[media_chamados_por_dia['evento'] != 'Geral'],
              x='evento',
         y='media_chamados_por_dia',
         color='evento',
         text='media_chamados_por_dia',
         title='Média Bienal de Chamados de "Perturbação de sossego" por dia por Evento' + f' <br><sup>Rock in Rio 2x acima do valor da Média Bienal ({media_geral})</sup><br><sup>Período: 01/01/2022 - 31/12/2023</sup>',
         labels={'evento': 'Evento', 'media_chamados_por_dia': 'Média de Chamados por Dia'})

fig.update_traces(textposition='outside', showlegend=False)
fig.update_layout(width=1080, bargap=0.2)

# Adiciona linha pontilhada com a média anual geral
fig.add_hline(y = media_geral,
              line_dash="dot",
              line_color="black",
              line_width=3,
              label=dict(
              text="Média Bienal = " + f"{media_geral}",
              textposition="end",
              font=dict(size=12, color="black")
              ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="de2a32b5-aa01-4cc4-8a4f-d07bf6b777c7" class="plotly-graph-div" style="height:525px; width:1080px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de2a32b5-aa01-4cc4-8a4f-d07bf6b777c7")) {                    Plotly.newPlot(                        "de2a32b5-aa01-4cc4-8a4f-d07bf6b777c7",                        [{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eM\u00e9dia de Chamados por Dia=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carnaval","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Carnaval","offsetgroup":"Carnaval","orientation":"v","showlegend":false,"text":[60.25],"textposition":"outside","x":["Carnaval"],"xaxis":"x","y":[60.25],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eM\u00e9dia de Chamados por Dia=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Reveillon","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Reveillon","offsetgroup":"Reveillon","orientation":"v","showlegend":false,"text":[46.33],"textposition":"outside","x":["Reveillon"],"xaxis":"x","y":[46.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Evento=%{x}\u003cbr\u003eM\u00e9dia de Chamados por Dia=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rock in Rio","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Rock in Rio","offsetgroup":"Rock in Rio","orientation":"v","showlegend":false,"text":[119.14],"textposition":"outside","x":["Rock in Rio"],"xaxis":"x","y":[119.14],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...
